# %%
import pandas as pd
import numpy as np
from scipy import stats
import math
import seaborn as sns
from mplsoccer import PyPizza, add_image, FontManager
import matplotlib.pyplot as plt
import matplotlib as mpl
from highlight_text import HighlightText, ax_text, fig_text

# %%
import matplotlib.font_manager

#matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
#Collect the data from the SmarterScout website.

metric = ['Attacking Output' , 'Shooting' , 'Dribbling' , 'Reception inside the Box' , 'Ball Retention' , 'Ground Duels in Poss.'
         , 'Link-Up Passing' , 'Progressive Passing'
         , 'Recovering' , 'Pressing' , 'Defending Quantity' , 'Defending Quality'
         , 'Aerial Duels in Open Play' , 'Ground Duels off Poss.']

values = [31 , 17 , 5 , 60 , 88 , 68 , 89 , 16 , 84 , 84 , 44 , 47 , 97 , 73]

#Check if your metrics and values are of the same size. The output should show 1. If it doesn't check both the lists.

len(metric)/len(values)
# Out:
# 1.0

# %%
fig = plt.figure(figsize=[18,18])


#Use a Horizontal Bar Graph by calling barh from matplotlib.

bar = plt.barh(metric , values , height=0.61 , color='#ff9a70' , edgecolor='none' , linewidth=1.2 , zorder=2
              , alpha=0.9)


#Scatter a circular point that we will use to showcase the value.

plt.scatter(31, 0, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(17, 1, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(5, 2, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(60, 3, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(88, 4, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(68, 5, s=1700, color='#181818' , edgecolor='#09E85E' , lw=2.8 , zorder=3)
plt.scatter(89, 6, s=1700, color='#181818' , edgecolor='#F5F749' , lw=2.8 , zorder=3)
plt.scatter(16, 7, s=1700, color='#181818' , edgecolor='#F5F749' , lw=2.8 , zorder=3)
plt.scatter(84, 8, s=1700, color='#181818' , edgecolor='#63ADF2' , lw=2.8 , zorder=3)
plt.scatter(84, 9, s=1700, color='#181818' , edgecolor='#63ADF2' , lw=2.8 , zorder=3)
plt.scatter(44, 10, s=1700, color='#181818' , edgecolor='#63ADF2' , lw=2.8 , zorder=3)
plt.scatter(47, 11, s=1700, color='#181818' , edgecolor='#63ADF2' , lw=2.8 , zorder=3)
plt.scatter(97, 12, s=1700, color='#181818' , edgecolor='#DB504A' , lw=2.8 , zorder=3)
plt.scatter(73, 13, s=1700, color='#181818' , edgecolor='#DB504A' , lw=2.8 , zorder=3)

#Use plt.text to plot the values. I use a difference of 1.3 in my x values, use that and play around
#to get the desired result.

plt.text(29.7, 0.13 , '31' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(15.7, 1.13 , '17' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(4.3, 2.13 , '5' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(58.7, 3.13 , '60' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(86.7, 4.13 , '88' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(66.6, 5.13 , '68' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(87.7, 6.13 , '89' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(14.6, 7.13 , '16' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(82.7, 8.13 , '84' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(82.7, 9.13 , '84' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(42.7, 10.13 , '44' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(45.7, 11.13 , '47' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(95.8, 12.13 , '97' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')
plt.text(71.6, 13.13 , '73' ,font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold')

#Set the color of each bar graph to group the metrics.

bar[0].set_facecolor('#09E85E')
bar[1].set_facecolor('#09E85E')
bar[2].set_facecolor('#09E85E')
bar[3].set_facecolor('#09E85E')
bar[4].set_facecolor('#09E85E')
bar[5].set_facecolor('#09E85E')
bar[6].set_facecolor('#F5F749')
bar[7].set_facecolor('#F5F749')
bar[8].set_facecolor('#63ADF2')
bar[9].set_facecolor('#63ADF2')
bar[10].set_facecolor('#63ADF2')
bar[11].set_facecolor('#63ADF2')
bar[12].set_facecolor('#DB504A')
bar[13].set_facecolor('#DB504A')


plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False

plt.tick_params(bottom = False)
plt.tick_params(left = False)
plt.tick_params(right = False)
plt.tick_params(top = False)
plt.yticks(font='Franklin Gothic Medium' , fontsize=26 , fontweight='bold' , color='#FFFFFF')
plt.xticks(font='Franklin Gothic Medium' , fontsize=24 , fontweight='bold' , color='#181818')
plt.gca().invert_yaxis()
#plt.gca().invert_xaxis()

plt.xlabel(None ,font='Franklin Gothic Medium' , color='#FFFFFF' , fontweight='bold' , fontsize=0 , labelpad=0)

plt.style.use("dark_background")
mpl.rc('axes',edgecolor='#181818' , linewidth=1.8)
for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#181818' 
for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.9'


plt.grid(color='#e9e8ed' , alpha=0.12 , zorder=1 , ls='--')

#for index, value in enumerate(data['Goalsp90'].round(2)):
  #plt.text(value+0.009, index+0.085,
            # str(value) ,font='Candara' , fontsize=24 , fontweight='bold' , color='#FFFFFF')
  
fig_text(
    0.400, 1.015, "<Fabinho Tavares - DM Profile>",font='Franklin Gothic Medium' , size=44,
    ha="center", color="#FFFFFF" , fontweight='bold' , highlight_textprops=[{'color':'#FFFFFF'}]
)

fig_text(
    0.400, 0.970,
    "Liverpool - PL 2022-23 | 1274 Minutes Played | Made by: @pranav_m28",font='Franklin Gothic Medium' , 
    size=28,
    ha="center", color="#FFFFFF" , fontweight='bold'
)

fig_text(
    0.400, 0.935,
    "Average SmarterScout Ratings divided into <Attacking>, <Passing>, <Defending> and <Aerial Ability>",
    font='Franklin Gothic Medium' , 
    size=26,
    ha="center", color="#FFFFFF" , fontweight='bold' , highlight_textprops=[{'color':'#09e85e'} , {'color':'#F5F749'}
                                                                           , {'color':'#63ADF2'} , {'color':'#DB504A'}]
)

#Use the code below to plot the line that separates the title and the graph.

sub = plt.subplot()
ax = sub.axis()
rec = plt.Rectangle((ax[-4] - 31.9, ax[0] - 1.3), (ax[1] - ax[0]) + 35, (ax[2] - ax[2]) + 0.0, fill=False, lw=2.2, linestyle="-")
rec = sub.add_patch(rec)
rec.set_clip_on(False)

#The code below is used to add the smarterscout logo. The logo can be found in the folder.

im = plt.imread('smarterscout-client.png')
newax = fig.add_axes([0.76, 0.99, 0.158, 0.95], anchor='SE', zorder=1)
newax.imshow(im)
newax.axis('off')



#im = plt.imread('lfctr.png')
#newax = fig.add_axes([-0.125, 0.96, 0.178, 0.95], anchor='SE', zorder=1)
#newax.imshow(im)
#newax.axis('off')



#plt.savefig('Fabinho SmarterScout Ratings.png' , dpi=300 , bbox_inches='tight')

plt.show()
